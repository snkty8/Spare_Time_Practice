# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np

# %%
#Import Combined Cleaned Kaggle Data
df = pd.read_csv('Cleaned_Combined_Kaggle_Data.csv')
df.head()
# Out:
#     Age Gender    Country     Formal_Education           Position  \
# 0  23.0   Male     France      Master’s degree  Software Engineer
# 1  42.0   Male      India  Professional degree  Software Engineer
# 2  42.0   Male  Australia      Master’s degree              Other
# 3  52.0   Male     France      Master’s degree     Data Scientist
# 4  23.0   Male      India      Master’s degree     Data Scientist
#
#    Years_Coding    Salary
# 0           2.0   34999.5
# 1           0.0    6249.5
# 2           2.0  274999.5
# 3          20.0   64999.5
# 4           5.0   12499.5

# %%
Gender = sns.pairplot(df,hue='Gender')
Gender

# %%
Women_df = df[df['Gender'] == 'Female']

# %%
Men_df = df[df['Gender'] == 'Male']

# %%
sns.boxplot(y='Salary',x='Age',data=Women_df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Salary'>

# %%
sns.boxplot(y='Salary',x='Age',data=Men_df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Salary'>

# %%
sns.boxplot(y='Salary',x='Years_Coding',data=Women_df)
# Out:
# <AxesSubplot:xlabel='Years_Coding', ylabel='Salary'>

# %%
sns.boxplot(y='Salary',x='Years_Coding',data=Men_df)
# Out:
# <AxesSubplot:xlabel='Years_Coding', ylabel='Salary'>

# %%
sns.countplot(x ='Gender', data = df)
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'Male'),
#   Text(1, 0, 'Female'),
#   Text(2, 0, 'Prefer to self-describe'),
#   Text(3, 0, 'Prefer not to say'),
#   Text(4, 0, 'Nonbinary')])

# %%
# from sklearn.preprocessing import OrdinalEncoder 
# encoder = OrdinalEncoder()
# cats = [['I prefer not to answer',0],
#        ['No formal education past high school',1],
#        ['Some college/university study without earning a bachelors degree',2],
#        ['Professional degree',3],
#        ['Bachelors degree',4],
#        ['Masters degree',5],
#        ['Doctoral degree',6]]
# encoded_cats = encoder.fit_transform(Women_df[['Formal_Education']])

# %%
# Women_df['Formal_Education'] = encoded_cats
# Out:
# C:\Users\snkty\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
Women_df['Formal_Education'].value_counts()
# Out:
# Master’s degree                                                      1750
# Bachelor’s degree                                                     779
# Doctoral degree                                                       760
# Professional degree                                                   131
# Some college/university study without earning a bachelor’s degree      47
# I prefer not to answer                                                 30
# No formal education past high school                                   16
# Name: Formal_Education, dtype: int64

# %%
y = np.array([1750, 779, 760, 131, 47,30,16])
mylabels = ['Master’s degree',
            'Bachelor’s degree',
            'Doctoral degree',
            'Professional degree',
            'Some college/university',
            'prefer not to answer',
            'No formal education past high school']

plt.pie(y, labels = mylabels, shadow = True, pctdistance=0.85)
plt.legend(title = "Women: Education Level", loc='center left', bbox_to_anchor=(2.0, 0.5))
plt.show()

# %%
#groupby the data by delivery type
data = Women_df.groupby(['Formal_Education']).mean()
data
# Out:
#                                                           Age  Years_Coding  \
# Formal_Education
# Bachelor’s degree                                   30.445443      4.721438
# Doctoral degree                                     37.738158     10.540789
# I prefer not to answer                              35.716667      6.633333
# Master’s degree                                     32.818857      6.281714
# No formal education past high school                31.187500      4.375000
# Professional degree                                 36.297710      5.984733
# Some college/university study without earning a...  34.138298      3.531915
#
#                                                           Salary
# Formal_Education
# Bachelor’s degree                                   39342.568036
# Doctoral degree                                     61697.861842
# I prefer not to answer                              20499.500000
# ...

# %%
Women_df['Position'].value_counts()
# Out:
# Data Scientist               1070
# Data Analyst                  565
# Software Engineer             437
# Other                         396
# Research Scientist            374
# Business Analyst              215
# Product/Project Manager       160
# Data Engineer                 123
# Statistician                   93
# Machine Learning Engineer      55
# DBA/Database Engineer          25
# Name: Position, dtype: int64

# %%
y = np.array([1070, 565, 437, 396, 374, 215, 160, 123, 93, 55, 25])
mylabels = ['Data Scientist',
            'Data Analyst',
            'Software Engineer',
            'Other',
            'Research Scientist',
            'Business Analyst',
            'Product/Project Manager',
            'Data Engineer',
            'Statistician',
            'Machine Learning Engineer',
            'DBA/Database Engineer']

#myexplode = [0.2, 0, 0, 0, 0, 0, 0]
plt.pie(y, labels = mylabels, pctdistance=0.85)
plt.legend(title = "Women: Job Title:", loc='center left', bbox_to_anchor=(1.5, 0.5))
plt.show()
